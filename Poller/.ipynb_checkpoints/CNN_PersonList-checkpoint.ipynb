# %%
'''
    need to open name list
    
    run the titles through something to see what names are in the title
    
    output articles with names in title to folder with person's name and file cnn.txt
'''

# %%
import os
import spacy

def returnName(line):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(line)
    
    people = []
    
    for ent in doc.ents:
        #print(ent.text, ent.label_)
        if ent.label_ == "PERSON":
            people.append(ent.text)
    
    return people


# add the title and url to the main file
def addOutputFile(titleLine, urlLine, name):    
    # makes sure there's no characters that would 
    # ruin the folder name
    if name[-1] == '\n':
        name = name.replace('\n', '')

    # get rid of the the extra CNN parts that get caught in the name finding
    if name.find("CNN"):
        name = name.replace('CNN', '')
    
    # get rid of 's in names
    if name.find("\'s"):
        name = name.replace("\'s", '')
    
    # getting rid of a list of characters that mess with the file naming structure
    char_to_replace = {'|': '',
                   ',': '',
                   ':': '',
                    '\"': '',
                    '\'': '',
                    '-': '',
                    ' ': '_'}
    
    name = name.translate(str.maketrans(char_to_replace))
    
    # creating the output file paths and names
    filePath = "ppl/" + name
    fileName = filePath + "/CNN_List.txt"
    try:
        os.mkdir(filePath)
        outputFile = open(fileName, "x")
    except:
        outputFile = open(fileName, "a")
    
    outputFile.seek(0, os.SEEK_END)
    
    toWrite = [titleLine, urlLine]
    
    outputFile.writelines(toWrite)
    outputFile.close()

    

    
    
print("\t\tStarting...")
    
inputFile = open("NameList.txt", "r")

inputFile.seek(0, os.SEEK_SET)

line = inputFile.readline()

print("\tFinding name...")
while line:

    #print(line)
    if line[:5] == "https":
        line = inputFile.readline()
        
    people = returnName(line)
    titleLine = line
    urlLine = inputFile.readline()
    
    for name in people:
        print(name)
        addOutputFile(titleLine, urlLine, name)
    
    line = inputFile.readline()

inputFile.close()

print("Done!")
# Out:
# 		Starting...
# 	Finding name...
# Carter
# Kristin Chenoweth
# Maleficent
# Amanda Kloots
# Elaine Welteroth - CNN
# Robert Joe
# Google Glass
# Eva Chen
# Kim
# Dainty
# Diwali
# Bruce Springsteen
# Alex Rodriguez
# Marvin Gaye
# Laurie Anderson
# Lou Reed
# | CNN Travel
# Natalie Portman
# al-Maliki
# Running of the Bulls
# Pamplona
# Brilliant Bus'
# Rob Ford
# Kerry
# Mali
# Benghazi
# Emil Erwin
# Emily Wickersham
# Richie Incognito
# Jonathan Martin's
# Katy Perry's
# Roar
# Cirque du Soleil
# Sylvester Stallone
# Melbourne Cup
# Miley Cyrus
# David Welch
# Katy Perry
# Justin Bieber
# William Swenson
# Mavericks
# Fatman
# Ironman
# Tawakkol Karman
# Paul Simon
# Gary Kubiak
# Mandela
# Vivien Leigh
# Kofi Annan
# Kendrick Johnson
# My Sister'
# Mali
# Rob Ford
# Russell Brand
# Gary Kubiak
# Molly Haskell
# Melbourne Cup:
# Gai Waterhouse
# Mississippi
# Terry McMillan's
# Wendy Williams
# Michelle Knight
# Phil
# Allie Brosh
# Michelle Knight
# Captor Castro
# Fukushima
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-df979b599873> in <module>
#      77         line = inputFile.readline()
#      78
# ---> 79     people = returnName(line)
#      80     titleLine = line
#      81     urlLine = inputFile.readline()
#
# <ipython-input-29-df979b599873> in returnName(line)
#       3
#       4 def returnName(line):
# ----> 5     nlp = spacy.load("en_core_web_sm")
#       6     doc = nlp(line)
#       7
#
# c:\users\jchic\appdata\local\programs\python\python39\lib\site-packages\spacy\__init__.py in load(name, **overrides)
#      28     if depr_path not in (True, False, None):
#      29         warnings.warn(Warnings.W001.format(path=depr_path), DeprecationWarning)
# ---> 30     return util.load_model(name, **overrides)
#      31
#      32
#
# c:\users\jchic\appdata\local\programs\python\python39\lib\site-packages\spacy\util.py in load_model(name, **overrides)
#     168             return load_model_from_link(name, **overrides)
#     169         if is_package(name):  # installed as package
# --> 170             return load_model_from_package(name, **overrides)
#     171         if Path(name).exists():  # path to model data directory
#     172             return load_model_from_path(Path(name), **overrides)
#
# c:\users\jchic\appdata\local\programs\python\python39\lib\site-packages\spacy\util.py in load_model_from_package(name, **overrides)
#     189     """Load a model from an installed package."""
#     190     cls = importlib.import_module(name)
# --> 191     return cls.load(**overrides)
#     192
#     193
#
# c:\users\jchic\appdata\local\programs\python\python39\lib\site-packages\en_core_web_sm\__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# c:\users\jchic\appdata\local\programs\python\python39\lib\site-packages\spacy\util.py in load_model_from_init_py(init_file, **overrides)
#     237     if not model_path.exists():
#     238         raise IOError(Errors.E052.format(path=path2str(data_path)))
# --> 239     return load_model_from_path(data_path, meta, **overrides)
#     240
#     241
#
# c:\users\jchic\appdata\local\programs\python\python39\lib\site-packages\spacy\util.py in load_model_from_path(model_path, meta, **overrides)
#     220             component = nlp.create_pipe(factory, config=config)
#     221             nlp.add_pipe(component, name=name)
# --> 222     return nlp.from_disk(model_path, exclude=disable)
#     223
#     224
#
# c:\users\jchic\appdata\local\programs\python\python39\lib\site-packages\spacy\language.py in from_disk(self, path, exclude, disable)
#     972             # Convert to list here in case exclude is (default) tuple
#     973             exclude = list(exclude) + ["vocab"]
# --> 974         util.from_disk(path, deserializers, exclude)
#     975         self._path = path
#     976         return self
#
# c:\users\jchic\appdata\local\programs\python\python39\lib\site-packages\spacy\util.py in from_disk(path, readers, exclude)
#     688         # Split to support file names like meta.json
#     689         if key.split(".")[0] not in exclude:
# --> 690             reader(path / key)
#     691     return path
#     692
#
# c:\users\jchic\appdata\local\programs\python\python39\lib\site-packages\spacy\language.py in <lambda>(p)
#     958         deserializers["meta.json"] = deserialize_meta
#     959         deserializers["vocab"] = deserialize_vocab
# --> 960         deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(
#     961             p, exclude=["vocab"]
#     962         )
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.from_disk()
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.from_bytes()
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer._load_special_tokenization()
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.add_special_case()
#
# vocab.pyx in spacy.vocab.Vocab.make_fused_token()
#
# vocab.pyx in spacy.vocab.Vocab.get_by_orth()
#
# vocab.pyx in spacy.vocab.Vocab._new_lexeme()
#
# c:\users\jchic\appdata\local\programs\python\python39\lib\site-packages\spacy\lang\lex_attrs.py in lower(string)
#     176
#     177 def lower(string):
# --> 178     return string.lower()
#     179
#     180
#
# KeyboardInterrupt:
