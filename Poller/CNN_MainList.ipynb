# %%
'''
    list goes title -> url
    
    need to check duplicates between master list & newly generated list
    
    need to copy from newly generated list to master list
'''

# %%
'''
    need to open the newly generated list
    
    need to open the master list
    
    need to check each of the new items against the master list
    
    if no dupes then copy it over
    
    otherwise drop it
    
    close both files
    
    delete the newly generated list?
'''

# %%
import os

# is the given line in the main file
def checkMainFile(line):
    try:
        mainFile = open("MainList.txt", "r")

        mainFile.seek(0, os.SEEK_SET)

        mainLine = mainFile.readline()
        while mainLine:
            #print(mainLine)
            if line == mainLine:
                #print("TRUE")
                mainFile.close()
                return True
            mainLine = mainFile.readline()

        mainFile.close()
    except:
        pass
    
    return False

# add the title and url to the main file
def addMainFile(titleLine, urlLine):
    mainFile = open("MainList.txt", "a")
    mainFile.seek(0, os.SEEK_END)
    
    #print(titleLine)
    #print(urlLine)
    
    toWrite = [titleLine, urlLine]
    
    mainFile.writelines(toWrite)
    #mainFile.write(urlLine)
    mainFile.close()

    
    

    
    
    
    
print("\t\tStarting...")
    
inputFile = open("../Scrapy/PoliticalPoller/PoliticalPoller/spiders/cnn.csv", "r")

#print(inputFile.read())
inputFile.seek(0, os.SEEK_SET)
#print("\n")

line = inputFile.readline()

while line:

    if line[:5] == "https":
        line = inputFile.readline()
    print(line)

    # is the title in the main file
    if not checkMainFile(line):
        titleLine = line
        urlLine = inputFile.readline()
        addMainFile(titleLine, urlLine)

    try:
        line = inputFile.readline()
    except:
        line = inputFile.readline()
        
        

inputFile.close()

print("\t\tDone!")
# Out:
# 		Starting...
# CNN Site Map - Main Index
#
# CNN Site Map - Articles for Year 2011
#
# CNN Site Map - Articles for Year 2020
#
# CNN Site Map - Articles for Year 2015
#
# CNN Site Map - Articles for Year 2019
#
# CNN Site Map - Articles for Year 2018
#
# CNN Site Map (Articles) for January - 2011
#
# CNN Site Map (Articles) for August - 2011
#
# CNN Site Map (Articles) for July - 2011
#
# CNN Site Map (Articles) for December - 2011
#
# CNN Site Map (Articles) for June - 2011
#
# CNN Site Map (Articles) for April - 2011
#
# CNN Site Map (Articles) for May - 2011
#
# CNN Site Map (Articles) for September - 2011
#
# CNN Site Map (Articles) for October - 2011
#
# CNN Site Map (Articles) for November - 2011
#
# White House: Behind-the-scenes moments
#
# CNN Site Map (Articles) for January - 2015
#
# Justices weigh whether inmate should die after mailroom slipup
#
# "CNN Student News Transcript - October 5, 2011"
#
# Hotmail wants to be hip again
#
# ...
