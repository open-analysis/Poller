# %%
#! python3
# threadedDownloadXkcd.py - Downloads XKCD comics using multiple threads.

import requests, os, bs4, threading
os.makedirs('xkcd', exist_ok=True)    # store comics in ./xkcd

def downloadXkcd(startComic, endComic):
    for urlNumber in range(startComic, endComic):
        # Download the page.
        print('Downloading page https://xkcd.com/%s...' % (urlNumber))
        res = requests.get('https://xkcd.com/%s' % (urlNumber))
        res.raise_for_status()

        soup = bs4.BeautifulSoup(res.text, 'html.parser')

        # Find the URL of the comic image.
        comicElem = soup.select('#comic img')
        if comicElem == []:
            print('Could not find comic image.')
        else:
            comicUrl = comicElem[0].get('src')
            # Download the image.
            print('Downloading image %s...' % (comicUrl))
            res = requests.get('https:' + comicUrl)
            res.raise_for_status()

            # Save the image to ./xkcd.
            imageFile = open(os.path.join('xkcd', os.path.basename(comicUrl)), 'wb')
            for chunk in res.iter_content(100000):
                imageFile.write(chunk)
            imageFile.close()

# Create and start the Thread objects.
downloadThreads = []             # a list of all the Thread objects
for i in range(0, 140, 10):    # loops 14 times, creates 14 threads
    start = i
    end = i + 9
    if start == 0:
        start = 1 # There is no comic 0, so set it to 1.
    downloadThread = threading.Thread(target=downloadXkcd, args=(start, end))
    downloadThreads.append(downloadThread)
    downloadThread.start()
    
# Wait for all threads to end.
for downloadThread in downloadThreads:
    downloadThread.join()
print('Done.')
# Out:
# Downloading page https://xkcd.com/1...
# Downloading page https://xkcd.com/10...
# Downloading page https://xkcd.com/20...
# Downloading page https://xkcd.com/30...
# Downloading page https://xkcd.com/40...
# Downloading page https://xkcd.com/50...
# Downloading page https://xkcd.com/60...
# Downloading page https://xkcd.com/70...
# Downloading page https://xkcd.com/80...
# Downloading page https://xkcd.com/90...Downloading page https://xkcd.com/100...Downloading page https://xkcd.com/110...
#
#
# Downloading page https://xkcd.com/120...Downloading page https://xkcd.com/130...
#
# Downloading image //imgs.xkcd.com/comics/ferret.jpg...
# Downloading image //imgs.xkcd.com/comics/light.jpg...Downloading image //imgs.xkcd.com/comics/pi.jpg...Downloading image //imgs.xkcd.com/comics/donner.jpg...
#
# Downloading image //imgs.xkcd.com/comics/penny_arcade.jpg...Downloading image //imgs.xkcd.com/comics/julia_stiles.jpg...
#
#
# Downloading image //imgs.xkcd.com/comics/super_bowl.jpg...
# Downloading image //imgs.xkcd.com/comics/dating_service.png...
# Downloading image //imgs.xkcd.com/comics/clark_gable.jpg...
# Downloading image //imgs.xkcd.com/comics/other_car.jpg...
# Downloading image //imgs.xkcd.com/comics/barrel_cropped_(1).jpg...
# Downloading image //imgs.xkcd.com/comics/family_circus.jpg...
# Downloading image //imgs.xkcd.com/comics/guitar_hero.jpg...
# Downloading page https://xkcd.com/31...
# Downloading page https://xkcd.com/21...
# Downloading image //imgs.xkcd.com/comics/jacket.jpg...
# Downloading page https://xkcd.com/51...
# Downloading page https://xkcd.com/131...
# Downloading page https://xkcd.com/11...
# Downloading page https://xkcd.com/111...
# Downloading page https://xkcd.com/41...
# Downloading page https://xkcd.com/81...
# Downloading page https://xkcd.com/121...
# Downloading page https://xkcd.com/61...
# Downloading page https://xkcd.com/2...
# Downloading image //imgs.xkcd.com/comics/barrel_mommies.jpg...
# Downloading image //imgs.xkcd.com/comics/fans.png...
# Downloading image //imgs.xkcd.com/comics/attention_shopper.jpg...
# Downloading image //imgs.xkcd.com/comics/barrel_part_5.jpg...
# Downloading image //imgs.xkcd.com/comics/balloon.png...
# Downloading image //imgs.xkcd.com/comics/mc_hammer_slide.png...
# Downloading page https://xkcd.com/95...
# Downloading page https://xkcd.com/67...
# Downloading page https://xkcd.com/125...
# Downloading image //imgs.xkcd.com/comics/blownapart_color.jpg...Downloading image //imgs.xkcd.com/comics/snapple.jpg...
#
# Downloading page https://xkcd.com/86...
# Downloading page https://xkcd.com/37...
# Downloading page https://xkcd.com/56...
# Downloading image //imgs.xkcd.com/comics/fourier.jpg...
# Downloading image //imgs.xkcd.com/comics/counter-red-spiders.jpg...
# Downloading image //imgs.xkcd.com/comics/the_sierpinski_penis_game.jpg...
# Downloading image //imgs.xkcd.com/comics/familiar.jpg...
# Downloading image //imgs.xkcd.com/comics/marketing_interview.png...
# Downloading image //imgs.xkcd.com/comics/nerd_girls.jpg...
# Downloading image //imgs.xkcd.com/comics/hyphen.jpg...
# Downloading page https://xkcd.com/135...
# Downloading page https://xkcd.com/48...
# Downloading page https://xkcd.com/27...
# Downloading image //imgs.xkcd.com/comics/the_cure.jpg...
# Downloading page https://xkcd.com/96...
# Downloading image //imgs.xkcd.com/comics/sony_microsoft_mpaa_riaa_apple.jpg...
# Downloading page https://xkcd.com/126...
# Downloading page https://xkcd.com/68...
# Downloading page https://xkcd.com/77...
# Downloading page https://xkcd.com/6...
# Downloading page https://xkcd.com/38...
# Downloading image //imgs.xkcd.com/comics/substitute.png...
# Downloading image //imgs.xkcd.com/comics/found.jpg...
# Downloading image //imgs.xkcd.com/comics/mail.png...
# Downloading image //imgs.xkcd.com/comics/meat_cereals.jpg...Downloading image //imgs.xkcd.com/comics/red_spiders_cometh.jpg...
#
# Downloading page https://xkcd.com/87...
# Downloading image //imgs.xkcd.com/comics/five_thirty.jpg...
# Downloading image //imgs.xkcd.com/comics/bored_with_the_internet.jpg...
# Downloading image //imgs.xkcd.com/comics/irony_color.jpg...
# Downloading image //imgs.xkcd.com/comics/apple_jacks.jpg...
# Downloading page https://xkcd.com/136...
# Downloading page https://xkcd.com/57...
# Downloading page https://xkcd.com/97...
# Downloading image //imgs.xkcd.com/comics/velociraptors.jpg...
# Downloading page https://xkcd.com/127...
# Downloading page https://xkcd.com/7...
# Downloading page https://xkcd.com/28...
# Downloading page https://xkcd.com/78...
# Downloading image //imgs.xkcd.com/comics/wait_for_me.jpg...
# Downloading image //imgs.xkcd.com/comics/science_fair.png...
# Downloading image //imgs.xkcd.com/comics/a_simple_plan.jpg...
# Downloading image //imgs.xkcd.com/comics/the_fast_and_the_furious.jpg...
# Downloading page https://xkcd.com/88...
# Downloading image //imgs.xkcd.com/comics/girl_sleeping_noline_(1).jpg...
# Downloading image //imgs.xkcd.com/comics/elefino.jpg...
# Downloading image //imgs.xkcd.com/comics/garfield.jpg...
# Downloading page https://xkcd.com/137...
# Downloading page https://xkcd.com/98...
# Downloading page https://xkcd.com/58...
# Downloading page https://xkcd.com/128...
# Downloading image //imgs.xkcd.com/comics/escher_wristband.jpg...
# Downloading page https://xkcd.com/8...
# Downloading image //imgs.xkcd.com/comics/why_do_you_love_me.jpg...
# Downloading image //imgs.xkcd.com/comics/dreams.png...
# Downloading image //imgs.xkcd.com/comics/fall_apart.jpg...
# Downloading image //imgs.xkcd.com/comics/red_spiders_small.jpg...
# Downloading image //imgs.xkcd.com/comics/dPain_over_dt.png...
# Downloading page https://xkcd.com/138...
# Downloading image //imgs.xkcd.com/comics/pointers.png...
# Done.
